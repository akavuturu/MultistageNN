# %%
import sys
import numpy
print(numpy.__version__)
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import time
from scipy.fft import fft, fftfreq
# Out:
# 1.26.4

# %%
class PhysicsInformedNN:
    # Initialize the class
    def __init__(self, t_u, x_u, layers, kappa, lt, ut, acts=0):

        self.scale = tf.reduce_max(tf.abs(x_u)) / 2
        x_u2 = x_u / self.scale
        actv = [tf.tanh, tf.sin]

        self.t_u = t_u
        self.x_u = x_u2
        self.datatype = t_u.dtype

        self.lt = lt
        self.ut = ut

        self.layers = layers
        self.kappa = kappa

        # determine the activation function to use
        self.actv = actv[acts]

        # Initialize NNs
        self.weights, self.biases = self.initialize_NN(layers)

        # Create a list including all training variables
        self.train_variables = self.weights + self.biases
        # Key point: anything updates in train_variables will be
        #            automatically updated in the original tf.Variable

        # define the loss function
        self.loss0 = self.scale ** 2
        self.loss = []
        self.loss_0 = self.loss_NN()

        self.optimizer_Adam = tf.optimizers.Adam()

    '''
    Functions used to establish the initial neural network
    ===============================================================
    '''

    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)

        for l in range(0, num_layers - 1):
            W = self.MPL_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=self.datatype))
            weights.append(W)
            biases.append(b)
        return weights, biases

    def MPL_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev, dtype=self.datatype))

    '''
    Functions used to building the physics-informed contrainst and loss
    ===============================================================
    '''

    def neural_net(self, X):
        weights = self.weights
        biases = self.biases

        num_layers = len(weights) + 1

        H = 2.0 * (X - self.lt) / (self.ut - self.lt) - 1.0

        W = weights[0]
        b = biases[0]
        H = self.actv(tf.add(self.kappa * tf.matmul(H, W), b))

        for l in range(1, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    @tf.function
    # calculate the physics-informed loss function
    def loss_NN(self):
        self.x_pred = self.neural_net(self.t_u)
        loss = tf.reduce_mean(tf.square(self.x_u - self.x_pred))
        return loss

    '''
    Functions used to define ADAM optimizers
    ===============================================================
    '''

    # define the function to apply the ADAM optimizer
    def adam_function(self):
        @tf.function
        def f():
            # calculate the loss
            loss_norm = self.loss_NN()
            loss_value = loss_norm * self.loss0
            # store loss value so we can retrieve later
            tf.py_function(f.loss.append, inp=[loss_value], Tout=[])

            # print out iteration & loss
            f.iter.assign_add(1)

            str_iter = tf.strings.as_string([f.iter])
            str_loss = tf.strings.as_string([loss_value], precision=4, scientific=True)

            str_print = tf.strings.join(["Iter: ", str_iter[0],
                                         ", loss: ", str_loss[0]])
            tf.cond(
                f.iter % 10 == 0,
                lambda: tf.print(str_print),
                lambda: tf.constant(True)  # return arbitrary for non-printing case
            )
            return loss_norm

        f.iter = tf.Variable(0)
        f.term = []
        f.loss = []
        return f

    def Adam_optimizer(self, nIter):
        varlist = self.train_variables
        func_adam = self.adam_function()
        for it in range(nIter):
            tf.keras.optimizers.Adam(func_adam, varlist)
            #self.optimizer_Adam.minimize(func_adam, varlist)
        return func_adam

    '''
    Functions used to define L-BFGS optimizers
    ===============================================================
    '''

    # A factory to create a function required by tfp.optimizer.lbfgs_minimize.
    def Lbfgs_function(self, varlist):
        # obtain the shapes of all trainable parameters in the model
        shapes = tf.shape_n(varlist)
        n_tensors = len(shapes)

        # we'll use tf.dynamic_stitch and tf.dynamic_partition later, so we need to
        # prepare required information first
        count = 0
        idx = []  # stitch indices
        part = []  # partition indices

        self.start_time = time.time()

        for i, shape in enumerate(shapes):
            n = np.product(shape)
            idx.append(tf.reshape(tf.range(count, count + n, dtype=tf.int32), shape))
            part.extend([i] * n)
            count += n

        part = tf.constant(part)

        def assign_new_model_parameters(params_1d):
            # A function updating the model's parameters with a 1D tf.Tensor.
            # Sub-function under function of class not need to input self

            params = tf.dynamic_partition(params_1d, part, n_tensors)
            for i, (shape, param) in enumerate(zip(shapes, params)):
                varlist[i].assign(tf.reshape(param, shape))

        @tf.function
        def f(params_1d):
            # A function that can be used by tfp.optimizer.lbfgs_minimize.
            # This function is created by function_factory.
            # Sub-function under function of class not need to input self

            # use GradientTape so that we can calculate the gradient of loss w.r.t. parameters
            with tf.GradientTape() as tape:
                # update the parameters in the model
                # this step is critical for self-defined function for L-BFGS
                assign_new_model_parameters(params_1d)
                # calculate the loss
                loss_norm = self.loss_NN()
                loss_value = loss_norm * self.loss0

            # calculate gradients and convert to 1D tf.Tensor
            grads = tape.gradient(loss_norm, varlist)
            grads = tf.dynamic_stitch(idx, grads)

            # store loss value so we can retrieve later
            tf.py_function(f.loss.append, inp=[loss_value], Tout=[])

            # print out iteration & loss
            f.iter.assign_add(1)

            str_iter = tf.strings.as_string([f.iter])
            str_loss = tf.strings.as_string([loss_value], precision=4, scientific=True)

            str_print = tf.strings.join(["Iter: ", str_iter[0],
                                         ", loss: ", str_loss[0]])
            tf.cond(
                f.iter % 3000 == 0,
                lambda: tf.print(str_print),
                lambda: tf.constant(True)  # return arbitrary for non-printing case
            )

            return loss_value, grads

        # store these information as members so we can use them outside the scope
        f.iter = tf.Variable(0)
        f.idx = idx
        f.part = part
        f.shapes = shapes
        f.assign_new_model_parameters = assign_new_model_parameters
        f.loss = []

        return f

    # define the function to apply the L-BFGS optimizer
    def Lbfgs_optimizer(self, nIter, varlist):

        func = self.Lbfgs_function(varlist)

        # convert initial model parameters to a 1D tf.Tensor
        init_params = tf.dynamic_stitch(func.idx, varlist)

        max_nIter = tf.cast(nIter / 3, dtype=tf.int32)

        # train the model with L-BFGS solver
        results = tfp.optimizer.lbfgs_minimize(
            value_and_gradients_function=func, initial_position=init_params,
            tolerance=1e-11, max_iterations=max_nIter)

        # after training, the final optimized parameters are still in results.position
        # so we have to manually put them back to the model
        func.assign_new_model_parameters(results.position)

        return func

    '''
    Function used for training the model
    ===============================================================
    '''

    def train(self, nIter, idxOpt):
        if idxOpt == 1:
            # mode 1: running the Adam optimization
            func_adam = self.Adam_optimizer(nIter)
            self.loss += func_adam.loss
        elif idxOpt == 2:
            # mode 2: running the Lbfgs optimization
            func_bfgs = self.Lbfgs_optimizer(nIter, self.train_variables)
            self.loss += func_bfgs.loss

    # @tf.function
    def predict(self, t):
        x_p = self.neural_net(t) * self.scale
        return x_p

# %%
noise = 0.0        
np.random.seed(234)
tf.random.set_seed(234)

def fun_test(t):
    # customize the function by the user
    #x = tf.math.log(t+2) * tf.cos(2*t + t**3)   # example 1
    x = (1 - (t**2) / 2) * np.cos(30*(t + 0.5*(t ** 3)))
    # x = tf.sin(2*t+1) + 0.2*tf.exp(1.3*t)  # example 2
    return x

Ntrain = 300
t = np.linspace(-1, 1, Ntrain)[:, None]
t_train = tf.cast(t, dtype=tf.float64)
x_train = fun_test(t_train)

# Domain bounds
lt = t.min(0)
ut = t.max(0)

# Number of test points
N_eval = 8000
t_eval = np.linspace(-1, 1, N_eval)[:, None]
t_eval = tf.cast(t_eval, dtype=tf.float64)
x_eval = fun_test(t_eval)

# %%
plt.figure(figsize=(10, 5))
ax = plt.plot(t_train, x_train[:, 0], 'r')
plt.grid(True)
plt.xlabel(r'$t$')
plt.ylabel(r'$u$')

plt.figure(figsize=(10, 5))
g = x_train.numpy().flatten()
grad_x = np.gradient(g, t_train.numpy().flatten())
print(max(grad_x)/(2 * np.pi))

ax = plt.plot(t_train, grad_x, 'b')
plt.grid(True)
plt.xlabel(r'$t$')
plt.ylabel(r'$\frac{du}{dt}$')
# Out:
# 6.1574044235092025
# Text(0, 0.5, '$\\frac{du}{dt}$')

# %%
# Calculate dominant frequency
N = len(g)
# Total time range
total_time_range = 2  # from -1 to 1

# Calculate the sample rate
sample_rate = N / total_time_range
print(f"Sample Rate: {sample_rate} Hz")

# Perform FFT
T = 1.0 / sample_rate
yf = fft(g)
xf = fftfreq(N, T)[:N//2]

# Plot the FFT spectrum
plt.figure(figsize=(10, 6))
plt.plot(xf, np.abs(yf[:N//2]) / N, 'b')
plt.plot(xf, np.abs(yf[:N//2]) / N, 'o')
plt.title("FFT Spectrum")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.xlim([0, 20])
plt.yticks(np.arange(0, 0.3, 0.1))
plt.grid(True)
plt.show()

# Identify the dominant frequency
dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
dominant_freq = xf[dominant_freq_idx]
magnitude = np.abs(yf[dominant_freq_idx]) / N

print(f"Dominant Frequency: {dominant_freq} Hz")
print(f"Magnitude: {magnitude}")
# Out:
# Sample Rate: 150.0 Hz
# Dominant Frequency: 5.5 Hz
# Magnitude: 0.20993312463094507

# %%
'''
Train a neural network to learn the error of stage 1
'''
# acts = 0 indicates selecting tanh as the activation function
layers = [1, 20, 20, 20, 1]
kappa0 =  2 * np.pi * dominant_freq
model_0 = PhysicsInformedNN(t_train, x_train, layers, kappa0, lt, ut, acts=0)
# start the first stage training
model_0.train(3000, 1)     # mode 1 use Adam
model_0.train(10000, 2)    # mode 2 use L-bfgs
x_pred = model_0.predict(t_eval)

error_x = np.linalg.norm(x_eval-x_pred, 2)/np.linalg.norm(x_eval, 2)
print('Error u: %e' % (error_x))
# Out:
# /var/folders/yr/kc2h8kxn6yn34sq117pyn2s00000gn/T/ipykernel_18012/2043776546.py:222: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   func = self.Lbfgs_function(varlist)
# Error u: 8.499816e-01

# %%
xmin = x_eval.numpy().min()
xmax = x_eval.numpy().max()

plt.figure(figsize=(10, 6))
plt.plot(t_eval, x_eval, 'b-', linewidth = 2, label = 'Exact')
plt.plot(t_eval, x_pred, 'r--', linewidth = 2, label = 'Prediction')
plt.ylabel('$u$', fontsize=15, rotation = 0)
plt.title('Stage 1', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.ylim([xmin,xmax])
plt.legend()

# %%
# calculate the error for the first stage
eg_1 = x_train - model_0.predict(t_train)
eps_1 = np.sqrt(1/t_train.shape[0] * sum([i**2 for i in eg_1]))
eg_1_norm = eg_1 / eps_1
g = eg_1_norm.numpy().flatten()

plt.figure(figsize=(10, 6))
plt.plot(t_train, eg_1, 'b', linewidth = 2, label = 'Error')
plt.ylabel('$x$', fontsize=15, rotation = 0)
plt.title('Error -- Stage 1', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.legend()

# %% [markdown]
# ## Stage 2

# %%
# Calculate dominant frequency of the error from stage 1
N = len(g)
sample_rate = N / total_time_range
print(f"Sample Rate: {sample_rate} Hz")
# Perform FFT
T = 1.0 / sample_rate
yf = fft(g)
xf = fftfreq(N, T)[:N//2]
dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
dominant_freq = xf[dominant_freq_idx]
magnitude = np.abs(yf[dominant_freq_idx]) / N

print(f"Dominant Frequency: {dominant_freq} Hz")
print(f"Magnitude: {magnitude}")

# Plot the FFT spectrum
plt.figure(figsize=(10, 6))
plt.plot(xf, np.abs(yf[:N//2]) / N, 'b')
plt.plot(xf, np.abs(yf[:N//2]) / N, 'o')
plt.title("FFT Spectrum -- Stage 1")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.xlim([0, 20])
plt.yticks(np.arange(0, 0.3, 0.1))
plt.grid(True)
plt.show()
# Out:
# Sample Rate: 150.0 Hz
# Dominant Frequency: 6.5 Hz
# Magnitude: 0.3762924417752848

# %%
# Calculate kappa for Stage 2
if dominant_freq < g.size / (6 * np.pi):
    kappa1 = 2 * np.pi * dominant_freq
    print('Kappa 1', kappa1)
else:
    print('Not enough data: Please Increase')
# Out:
# Kappa 1 40.840704496667314

# %%
'''
Train Neural Network (the error)
'''
layers = [1, 20, 20, 20, 1]
model_1 = PhysicsInformedNN(t_train, eg_1_norm, layers, kappa1, lt, ut, acts=1)
# start the second stage training
model_1.train(5000, 1)    # mode 1 use Adam
model_1.train(20000, 2)   # mode 2 use L-bfgs
eg_1_pred = model_1.predict(t_eval)
# combining the result from first and second stage
x_p = x_pred + eps_1 * eg_1_pred

error_x = np.linalg.norm(x_eval-x_p, 2)/np.linalg.norm(x_eval, 2)
print('Error u: %e' % (error_x))
# Out:
# /var/folders/yr/kc2h8kxn6yn34sq117pyn2s00000gn/T/ipykernel_18012/2043776546.py:222: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   func = self.Lbfgs_function(varlist)
# Iter: 3000, loss: 4.3002e-03
# Iter: 6000, loss: 1.5887e-03
# Iter: 9000, loss: 1.1180e-03
# Iter: 12000, loss: 8.2887e-04
# Iter: 15000, loss: 5.5144e-04
# Iter: 18000, loss: 4.0661e-04
# Error u: 2.319836e-02

# %%
plt.figure(figsize=(10, 6))
plt.plot(t_eval, x_eval, 'b-', linewidth = 2, label = 'Exact')
plt.plot(t_eval, x_p, 'r--', linewidth = 2, label = 'Prediction')
plt.ylabel('$u$', fontsize=15, rotation = 0)
plt.title('Stage 2', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.ylim([xmin,xmax])
plt.legend()

# %%
# calculate the residue for the second stage
eg_2 = x_train - model_0.predict(t_train) - eps_1 * model_1.predict(t_train)
eps_2 = np.sqrt(1/t_train.shape[0] * sum([i**2 for i in eg_2]))
eg_2_norm = eg_2 / eps_2
g = eg_2_norm.numpy().flatten()


plt.figure(figsize=(10, 6))
plt.plot(t_train, eg_2, 'b', linewidth = 2, label = 'Error')
plt.ylabel('$u$', fontsize=15, rotation = 0)
plt.title('Error -- Stage 2', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.ylim([xmin,xmax])
plt.legend()

# %% [markdown]
# ## Stage 3

# %%
# Calculate dominant frequency of the error from stage 1
N = len(g)
sample_rate = N / total_time_range
print(f"Sample Rate: {sample_rate} Hz")
# Perform FFT
T = 1.0 / sample_rate
yf = fft(g)
xf = fftfreq(N, T)[:N//2]
dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
dominant_freq = xf[dominant_freq_idx]
magnitude = np.abs(yf[dominant_freq_idx]) / N

print(f"Dominant Frequency: {dominant_freq} Hz")
print(f"Magnitude: {magnitude}")
# Out:
# Sample Rate: 150.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.14395370652122763

# %%
'''
Second stage of training
'''
while dominant_freq > g.size / (6 * np.pi):
    print('Increasing data')
    Ntrain = Ntrain  + 20
    t = np.linspace(-1.0, 1.0, Ntrain)[:, None]
    t_train = tf.cast(t, dtype=tf.float64)
    x_train = fun_test(t_train)
    eg_2 = x_train - model_0.predict(t_train) - eps_1 * model_1.predict(t_train)
    eps_2 = np.sqrt(1/t_train.shape[0] * sum([i**2 for i in eg_2]))
    eg_2_norm = eg_2 / eps_2
    g = eg_2_norm.numpy().flatten()
    N = len(g)
    sample_rate = N / total_time_range
    print(f"Sample Rate: {sample_rate} Hz")
    # Perform FFT
    T = 1.0 / sample_rate
    yf = fft(g)
    xf = fftfreq(N, T)[:N//2]
    dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
    dominant_freq = xf[dominant_freq_idx]
    magnitude = np.abs(yf[dominant_freq_idx]) / N
    
    print(f"Dominant Frequency: {dominant_freq} Hz")
    print(f"Magnitude: {magnitude}")



# Plot the FFT spectrum
plt.figure(figsize=(10, 6))
plt.plot(xf, np.abs(yf[:N//2]) / N, 'b')
plt.plot(xf, np.abs(yf[:N//2]) / N, 'o')
plt.title("FFT Spectrum Error Stage 2")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.xlim([0, 20])
plt.yticks(np.arange(0, 0.3, 0.1))
plt.grid(True)
plt.show()


print('Ntrain new', Ntrain)
kappa2 = 2 * np.pi * dominant_freq
print(kappa2)
# Out:
# Increasing data
# Sample Rate: 160.0 Hz
# Dominant Frequency: 66.0 Hz
# Magnitude: 0.12668026993881892
# Increasing data
# Sample Rate: 170.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.11985114951760005
# Increasing data
# Sample Rate: 180.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.13757865532980762
# Increasing data
# Sample Rate: 190.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.11566714652079342
# Increasing data
# Sample Rate: 200.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.13862095167547708
# Increasing data
# Sample Rate: 210.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12342628195046633
# Increasing data
# Sample Rate: 220.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12153301637985374
# Increasing data
# Sample Rate: 230.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12707166244853196
# Increasing data
# Sample Rate: 240.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.11754033102564532
# Increasing data
# Sample Rate: 250.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.1259006896603497
# Increasing data
# Sample Rate: 260.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.1236610388628341
# Increasing data
# Sample Rate: 270.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12436944300325524
# Increasing data
# Sample Rate: 280.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12626063671321214
# Increasing data
# Sample Rate: 290.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12493078543067644
# Increasing data
# Sample Rate: 300.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12445540943426427
# Increasing data
# Sample Rate: 310.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.1250817985435767
# Increasing data
# Sample Rate: 320.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12363955940407748
# Increasing data
# Sample Rate: 330.0 Hz
# Dominant Frequency: 34.0 Hz
# Magnitude: 0.12513616566883087
# Ntrain new 660
# 213.62830044410595

# %%
# (acts = 1 indicates selecting sin as the activation function)
layers = [1, 20, 20, 20, 1]
model_2 = PhysicsInformedNN(t_train, eg_2_norm, layers, kappa2, lt, ut, acts=1)
# start the third stage training
model_2.train(5000, 1)      # mode 1 use Adam
model_2.train(20000, 2)     # mode 2 use L-bfgs
eg_2_pred = model_2.predict(t_eval)
# combining the result from first, second and third stages
x_p = x_pred + eps_1 * eg_1_pred + eps_2 * eg_2_pred

error_x = np.linalg.norm(x_eval-x_p, 2)/np.linalg.norm(x_eval, 2)
print('Error u: %e' % (error_x))
# Out:
# /var/folders/yr/kc2h8kxn6yn34sq117pyn2s00000gn/T/ipykernel_18012/2043776546.py:222: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   func = self.Lbfgs_function(varlist)
# Iter: 3000, loss: 2.6004e-02
# Iter: 6000, loss: 3.4498e-03
# Iter: 9000, loss: 7.4698e-04
# Iter: 12000, loss: 1.6332e-04
# Iter: 15000, loss: 3.6813e-05
# Iter: 18000, loss: 8.6144e-06
# Iter: 21000, loss: 1.9401e-06
# Iter: 24000, loss: 5.0813e-07
# Iter: 27000, loss: 1.4863e-07
# Error u: 1.364632e-02

# %%
# calculate the residue for the second stage
eg_3 = x_train - model_0.predict(t_train)- eps_1 * model_1.predict(t_train)- eps_2 * model_2.predict(t_train)
eps_3 = np.sqrt(1/t_train.shape[0] * sum([i**2 for i in eg_3]))
eg_3_norm = eg_3 / eps_3
g = eg_3_norm.numpy().flatten()


plt.figure(figsize=(10, 6))
plt.plot(t_train, eg_3, 'r-', linewidth = 2, label = 'Error')
plt.ylabel('$x$', fontsize=15, rotation = 0)
plt.title('Stage 3', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.legend()

# %% [markdown]
# ## 3rd stage

# %%
N = len(g)
sample_rate = N / total_time_range
print(f"Sample Rate: {sample_rate} Hz")
# Perform FFT
T = 1.0 / sample_rate
yf = fft(g)
xf = fftfreq(N, T)[:N//2]
dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
dominant_freq = xf[dominant_freq_idx]
magnitude = np.abs(yf[dominant_freq_idx]) / N

print(f"Dominant Frequency: {dominant_freq} Hz")
print(f"Magnitude: {magnitude}")
# Out:
# Sample Rate: 330.0 Hz
# Dominant Frequency: 75.0 Hz
# Magnitude: 0.11290129127150296

# %%
'''
Third stage of training
'''
while dominant_freq > g.size / (6 * np.pi):
    print('Increasing data')
    Ntrain = Ntrain  + 20
    t = np.linspace(-1.0, 1.0, Ntrain)[:, None]
    t_train = tf.cast(t, dtype=tf.float64)
    x_train = fun_test(t_train)
    eg_3 = x_train - model_0.predict(t_train) - eps_1 * model_1.predict(t_train)  - eps_2 * model_2.predict(t_train)
    eps_3 = np.sqrt(1/t_train.shape[0] * sum([i**2 for i in eg_3]))
    eg_3_norm = eg_3 / eps_3
    g = eg_3_norm.numpy().flatten()
    N = len(g)
    sample_rate = N / total_time_range
    #print(f"Sample Rate: {sample_rate} Hz")
    # Perform FFT
    T = 1.0 / sample_rate
    yf = fft(g)
    xf = fftfreq(N, T)[:N//2]
    dominant_freq_idx = np.argmax(np.abs(yf[:N//2]))
    dominant_freq = xf[dominant_freq_idx]
    magnitude = np.abs(yf[dominant_freq_idx]) / N
    
print(f"Dominant Frequency: {dominant_freq} Hz")
print(f"Magnitude: {magnitude}")


# Plot the FFT spectrum
plt.figure(figsize=(10, 6))
plt.plot(xf, np.abs(yf[:N//2]) / N, 'b')
plt.plot(xf, np.abs(yf[:N//2]) / N, 'o')
plt.title("FFT Spectrum Error Stage 3")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.xlim([0, 20])
plt.yticks(np.arange(0, 0.3, 0.1))
plt.grid(True)
plt.show()


print('Ntrain new', Ntrain)
kappa3 = 2 * np.pi * dominant_freq
print(kappa3)
# Out:
# Increasing data
# Sample Rate: 340.0 Hz
# Dominant Frequency: 167.0 Hz
# Magnitude: 0.0989524914340679
# Increasing data
# Sample Rate: 350.0 Hz
# Dominant Frequency: 141.0 Hz
# Magnitude: 0.09248340916815245
# Increasing data
# Sample Rate: 360.0 Hz
# Dominant Frequency: 167.0 Hz
# Magnitude: 0.09369565068720682
# Increasing data
# Sample Rate: 370.0 Hz
# Dominant Frequency: 182.5 Hz
# Magnitude: 0.09615970025850017
# Increasing data
# Sample Rate: 380.0 Hz
# Dominant Frequency: 167.0 Hz
# Magnitude: 0.103664527052765
# Increasing data
# Sample Rate: 390.0 Hz
# Dominant Frequency: 182.5 Hz
# Magnitude: 0.09921228125296705
# Increasing data
# Sample Rate: 400.0 Hz
# Dominant Frequency: 192.0 Hz
# Magnitude: 0.08465030148813836
# Increasing data
# Sample Rate: 410.0 Hz
# Dominant Frequency: 161.5 Hz
# Magnitude: 0.10122078528406124
# Increasing data
# Sample Rate: 420.0 Hz
# Dominant Frequency: 205.5 Hz
# Magnitude: 0.08653225004692094
# Increasing data
# Sample Rate: 430.0 Hz
# Dominant Frequency: 163.0 Hz
# Magnitude: 0.08279124623421606
# Increasing data
# Sample Rate: 440.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.11515137699520675
# Increasing data
# Sample Rate: 450.0 Hz
# Dominant Frequency: 196.5 Hz
# Magnitude: 0.08921323905612355
# Increasing data
# Sample Rate: 460.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0947213757904558
# Increasing data
# Sample Rate: 470.0 Hz
# Dominant Frequency: 182.5 Hz
# Magnitude: 0.09057002462605418
# Increasing data
# Sample Rate: 480.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.093299157155294
# Increasing data
# Sample Rate: 490.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08364667402437244
# Increasing data
# Sample Rate: 500.0 Hz
# Dominant Frequency: 210.5 Hz
# Magnitude: 0.08510486383711789
# Increasing data
# Sample Rate: 510.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08253399172391075
# Increasing data
# Sample Rate: 520.0 Hz
# Dominant Frequency: 196.5 Hz
# Magnitude: 0.07947393210716551
# Increasing data
# Sample Rate: 530.0 Hz
# Dominant Frequency: 208.0 Hz
# Magnitude: 0.07605216352793971
# Increasing data
# Sample Rate: 540.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07510698342689703
# Increasing data
# Sample Rate: 550.0 Hz
# Dominant Frequency: 231.0 Hz
# Magnitude: 0.08911708848944047
# Increasing data
# Sample Rate: 560.0 Hz
# Dominant Frequency: 254.0 Hz
# Magnitude: 0.08331821373777822
# Increasing data
# Sample Rate: 570.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07035297900506661
# Increasing data
# Sample Rate: 580.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.06871985893123754
# Increasing data
# Sample Rate: 590.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07828517723845366
# Increasing data
# Sample Rate: 600.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07572690543729058
# Increasing data
# Sample Rate: 610.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07853469341661214
# Increasing data
# Sample Rate: 620.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07477259108781499
# Increasing data
# Sample Rate: 630.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08242769794901443
# Increasing data
# Sample Rate: 640.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08284011416634399
# Increasing data
# Sample Rate: 650.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0723563792685991
# Increasing data
# Sample Rate: 660.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08174518257324277
# Increasing data
# Sample Rate: 670.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.076532139640809
# Increasing data
# Sample Rate: 680.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08199618870147882
# Increasing data
# Sample Rate: 690.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07697008421374392
# Increasing data
# Sample Rate: 700.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07592206729576079
# Increasing data
# Sample Rate: 710.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08122498434494022
# Increasing data
# Sample Rate: 720.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07610509246383988
# Increasing data
# Sample Rate: 730.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07785969328235622
# Increasing data
# Sample Rate: 740.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08225669417938362
# Increasing data
# Sample Rate: 750.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08059146269423147
# Increasing data
# Sample Rate: 760.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08061225897441994
# Increasing data
# Sample Rate: 770.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07837461644943841
# Increasing data
# Sample Rate: 780.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07976841060702436
# Increasing data
# Sample Rate: 790.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07490751475982355
# Increasing data
# Sample Rate: 800.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08188793615421337
# Increasing data
# Sample Rate: 810.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07838150285737158
# Increasing data
# Sample Rate: 820.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08170604026749807
# Increasing data
# Sample Rate: 830.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07864755113487387
# Increasing data
# Sample Rate: 840.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07823116531816948
# Increasing data
# Sample Rate: 850.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07818294912650875
# Increasing data
# Sample Rate: 860.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07910946629226892
# Increasing data
# Sample Rate: 870.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07755499101122193
# Increasing data
# Sample Rate: 880.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07951972691408656
# Increasing data
# Sample Rate: 890.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07858438282636787
# Increasing data
# Sample Rate: 900.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07854067070359579
# Increasing data
# Sample Rate: 910.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07934727452104236
# Increasing data
# Sample Rate: 920.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07825220085568958
# Increasing data
# Sample Rate: 930.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08095803464535468
# Increasing data
# Sample Rate: 940.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07946344303560762
# Increasing data
# Sample Rate: 950.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07966362941556833
# Increasing data
# Sample Rate: 960.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07917310056654282
# Increasing data
# Sample Rate: 970.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07866284745743433
# Increasing data
# Sample Rate: 980.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.08081063167291667
# Increasing data
# Sample Rate: 990.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07960847453292533
# Increasing data
# Sample Rate: 1000.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07907723787432534
# Increasing data
# Sample Rate: 1010.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0790593344919828
# Increasing data
# Sample Rate: 1020.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07940883366628985
# Increasing data
# Sample Rate: 1030.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07979722903673472
# Increasing data
# Sample Rate: 1040.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07913523265595179
# Increasing data
# Sample Rate: 1050.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07938944077321664
# Increasing data
# Sample Rate: 1060.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07938422403623027
# Increasing data
# Sample Rate: 1070.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07913109128633458
# Increasing data
# Sample Rate: 1080.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07906513406966705
# Increasing data
# Sample Rate: 1090.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07916575893361275
# Increasing data
# Sample Rate: 1100.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07889851341102506
# Increasing data
# Sample Rate: 1110.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07928875623374551
# Increasing data
# Sample Rate: 1120.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07916262769950697
# Increasing data
# Sample Rate: 1130.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07915553534765706
# Increasing data
# Sample Rate: 1140.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07933032205029344
# Increasing data
# Sample Rate: 1150.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07914016375292032
# Increasing data
# Sample Rate: 1160.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0790892775724833
# Increasing data
# Sample Rate: 1170.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07901560757926537
# Increasing data
# Sample Rate: 1180.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07905784729785413
# Increasing data
# Sample Rate: 1190.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07889229827903105
# Increasing data
# Sample Rate: 1200.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07901396017006393
# Increasing data
# Sample Rate: 1210.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07883707473448562
# Increasing data
# Sample Rate: 1220.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07880776246387662
# Increasing data
# Sample Rate: 1230.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07889323263865318
# Increasing data
# Sample Rate: 1240.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0787430218539788
# Increasing data
# Sample Rate: 1250.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07864776367981596
# Increasing data
# Sample Rate: 1260.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07891650240557538
# Increasing data
# Sample Rate: 1270.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0788549253708083
# Increasing data
# Sample Rate: 1280.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07864681194794775
# Increasing data
# Sample Rate: 1290.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07858105358493676
# Increasing data
# Sample Rate: 1300.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07881808552974054
# Increasing data
# Sample Rate: 1310.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07854948876384533
# Increasing data
# Sample Rate: 1320.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07864647582078645
# Increasing data
# Sample Rate: 1330.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07861554796792698
# Increasing data
# Sample Rate: 1340.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0787271792678476
# Increasing data
# Sample Rate: 1350.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07864723454298446
# Increasing data
# Sample Rate: 1360.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07857808744256677
# Increasing data
# Sample Rate: 1370.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07854605593015039
# Increasing data
# Sample Rate: 1380.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07853158632288544
# Increasing data
# Sample Rate: 1390.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07839739745550732
# Increasing data
# Sample Rate: 1400.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07856086449491512
# Increasing data
# Sample Rate: 1410.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07849554008313356
# Increasing data
# Sample Rate: 1420.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07849506840261716
# Increasing data
# Sample Rate: 1430.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07839270108059841
# Increasing data
# Sample Rate: 1440.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07839051116700117
# Increasing data
# Sample Rate: 1450.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07836866051484775
# Increasing data
# Sample Rate: 1460.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0783259057545493
# Increasing data
# Sample Rate: 1470.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07831564260221216
# Increasing data
# Sample Rate: 1480.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07830311562802458
# Increasing data
# Sample Rate: 1490.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07832884756797906
# Increasing data
# Sample Rate: 1500.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07826394522196284
# Increasing data
# Sample Rate: 1510.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07826360623433869
# Increasing data
# Sample Rate: 1520.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07825527913332449
# Increasing data
# Sample Rate: 1530.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07822441994525842
# Increasing data
# Sample Rate: 1540.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07817291283160901
# Increasing data
# Sample Rate: 1550.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07817535236846286
# Increasing data
# Sample Rate: 1560.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07814630637154303
# Increasing data
# Sample Rate: 1570.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07810970748468553
# Increasing data
# Sample Rate: 1580.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07808385486172657
# Increasing data
# Sample Rate: 1590.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07806730819186684
# Increasing data
# Sample Rate: 1600.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07806305958039138
# Increasing data
# Sample Rate: 1610.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0780142292309826
# Increasing data
# Sample Rate: 1620.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07800404198523644
# Increasing data
# Sample Rate: 1630.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07798610825062795
# Increasing data
# Sample Rate: 1640.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07794477790935726
# Increasing data
# Sample Rate: 1650.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07791530009239252
# Increasing data
# Sample Rate: 1660.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07791437577079915
# Increasing data
# Sample Rate: 1670.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0778804609238763
# Increasing data
# Sample Rate: 1680.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07787491656106593
# Increasing data
# Sample Rate: 1690.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0778368389090488
# Increasing data
# Sample Rate: 1700.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.07783204149549097
# Increasing data
# Sample Rate: 1710.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07779358768923368
# Increasing data
# Sample Rate: 1720.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07777350911062642
# Increasing data
# Sample Rate: 1730.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07774410739054259
# Increasing data
# Sample Rate: 1740.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0777343786179383
# Increasing data
# Sample Rate: 1750.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07772127677171378
# Increasing data
# Sample Rate: 1760.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07770854325497224
# Increasing data
# Sample Rate: 1770.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07767622739244459
# Increasing data
# Sample Rate: 1780.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0776518051454312
# Increasing data
# Sample Rate: 1790.0 Hz
# Dominant Frequency: 209.00000000000006 Hz
# Magnitude: 0.0776176237467767
# Increasing data
# Sample Rate: 1800.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07761459606757526
# Increasing data
# Sample Rate: 1810.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0775910398186865
# Increasing data
# Sample Rate: 1820.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07756585289077929
# Increasing data
# Sample Rate: 1830.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07754969061741235
# Increasing data
# Sample Rate: 1840.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07752475887571339
# Increasing data
# Sample Rate: 1850.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07750279601604046
# Increasing data
# Sample Rate: 1860.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07748745924315559
# Increasing data
# Sample Rate: 1870.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07746395794336668
# Increasing data
# Sample Rate: 1880.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07744675282135743
# Increasing data
# Sample Rate: 1890.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07742585717054501
# Increasing data
# Sample Rate: 1900.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0774076323146524
# Increasing data
# Sample Rate: 1910.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0773878350118812
# Increasing data
# Sample Rate: 1920.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07736942825985973
# Increasing data
# Sample Rate: 1930.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07735038738370845
# Increasing data
# Sample Rate: 1940.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.0773300923654586
# Increasing data
# Sample Rate: 1950.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07731137888854232
# Increasing data
# Sample Rate: 1960.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07728704086822027
# Increasing data
# Sample Rate: 1970.0 Hz
# Dominant Frequency: 209.0 Hz
# Magnitude: 0.07727174758031166
# Ntrain new 3940
# 1313.1857292005336

# %%
# (acts = 1 indicates selecting sin as the activation function)
layers = [1, 30, 30, 30, 30, 1]
model_3 = PhysicsInformedNN(t_train, eg_3_norm, layers, kappa3, lt, ut, acts=1)
# start the third stage training
model_3.train(5000, 1)      # mode 1 use Adam
model_3.train(30000, 2)     # mode 2 use L-bfgs
eg_3_pred = model_3.predict(t_eval)
# combining the result from first, second and third stages
x_p = x_pred + eps_1 * eg_1_pred + eps_2 * eg_2_pred + eps_3 * eg_3_pred

error_x = np.linalg.norm(x_eval-x_p, 2)/np.linalg.norm(x_eval, 2)
print('Error u: %e' % (error_x))
# Out:
# /var/folders/yr/kc2h8kxn6yn34sq117pyn2s00000gn/T/ipykernel_18012/2043776546.py:222: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   func = self.Lbfgs_function(varlist)
# Iter: 3000, loss: 7.3929e-01
# Iter: 6000, loss: 4.9537e-01
# Iter: 9000, loss: 3.5620e-01
# Iter: 12000, loss: 2.6424e-01
# Iter: 15000, loss: 1.9838e-01
# Iter: 18000, loss: 1.5713e-01
# Iter: 21000, loss: 1.2524e-01
# Iter: 24000, loss: 9.7912e-02
# Iter: 27000, loss: 8.0412e-02
# Iter: 30000, loss: 6.7363e-02
# Error u: 1.043393e-02

# %%
plt.figure(figsize=(10, 6))
plt.plot(t_train, eg_3, 'b', linewidth = 2, label = 'Exact')
plt.plot(t_eval, eg_3_pred * eps_3, 'r-.', linewidth = 2, label = 'Prediction')
plt.ylabel('$x$', fontsize=15, rotation = 0)
plt.title('Stage 4', fontsize=10)
plt.xlim([-1.0, 1.0])
plt.legend()

# %%
# combine the loss of all four stages of training
loss = np.array(model_0.loss + model_1.loss + model_2.loss + model_3.loss)
